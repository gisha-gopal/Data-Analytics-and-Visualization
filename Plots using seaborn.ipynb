# %%
import pandas as pd
import seaborn as sns
dataset = pd.read_csv('DAV_Project_dataset.csv')
sns.set(color_codes=True)

# %%
dataset.head()
# Out:
#    Year      Country          Region  Happiness_Rank  Happiness_Score  \
# 0  2015  Switzerland  Western Europe               1            7.587
# 1  2015      Iceland  Western Europe               2            7.561
# 2  2015      Denmark  Western Europe               3            7.527
# 3  2015       Norway  Western Europe               4            7.522
# 4  2015       Canada   North America               5            7.427
#
#    Economy_GDP   Family  Life_Expectancy  Freedom  Government_Corruption  \
# 0      1.39651  1.34951          0.94143  0.66557                0.41978
# 1      1.30232  1.40223          0.94784  0.62877                0.14145
# 2      1.32548  1.36058          0.87464  0.64938                0.48357
# 3      1.45900  1.33095          0.88521  0.66973                0.36503
# 4      1.32629  1.32261          0.90563  0.63297                0.32957
#
#    Generosity  Dystopia_Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   775 non-null    int64
#  1   Country                775 non-null    object
#  2   Region                 775 non-null    object
#  3   Happiness_Rank         775 non-null    int64
#  4   Happiness_Score        775 non-null    float64
#  5   Economy_GDP            775 non-null    float64
#  6   Family                 775 non-null    float64
#  7   Life_Expectancy        775 non-null    float64
#  8   Freedom                775 non-null    float64
#  9   Government_Corruption  775 non-null    float64
#  10  Generosity             774 non-null    float64
#  11  Dystopia_Residual      469 non-null    float64
# dtypes: float64(8), int64(2), object(2)
# memory usage: 72.8+ KB

# %%
sns.barplot(dataset['Family'],dataset['Happiness_Score'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Family', ylabel='Happiness_Score'>

# %%
sns.barplot(dataset['Happiness_Score'],dataset['Economy_GDP'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Economy_GDP'>

# %%
sns.distplot(dataset['Happiness_Score'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Density'>

# %%
sns.distplot(dataset['Economy_GDP'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Economy_GDP', ylabel='Density'>

# %%
sns.distplot(dataset['Life_Expectancy'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Life_Expectancy', ylabel='Density'>

# %%
sns.jointplot(dataset['Happiness_Score'],dataset['Economy_GDP'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(dataset['Happiness_Score'],dataset['Economy_GDP'], kind='hex')
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(dataset['Happiness_Score'],dataset['Economy_GDP'], kind='kde')
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.pairplot(dataset[['Happiness_Score','Economy_GDP','Life_Expectancy','Family','Government_Corruption','Generosity','Freedom','Dystopia_Residual']])

# %%
sns.stripplot(dataset['Happiness_Score'],dataset['Region'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Region'>

# %%
sns.stripplot(dataset['Happiness_Score'],dataset['Region'], jitter=True)
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Region'>

# %%
sns.swarmplot(dataset['Happiness_Score'],dataset['Life_Expectancy'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Life_Expectancy'>

# %%
sns.countplot(dataset['Region'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Region', ylabel='count'>

# %%
sns.pointplot(dataset['Happiness_Score'],dataset['Economy_GDP'], hue=dataset['Region'])
# Out:
# C:\Users\gisha\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Happiness_Score', ylabel='Economy_GDP'>

# %%
sns.lmplot(x="Happiness_Score",y="Economy_GDP", hue="Region", data=dataset)
